# %%
import os as os
import pandas as pd
import statsmodels.api as sm
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
data = pd.read_csv('MERGED2016_17_PP.csv',low_memory = False)
data
# Out:
#         UNITID     OPEID  OPEID6  \
# 0       100654    100200    1002
# 1       100663    105200    1052
# 2       100690   2503400   25034
# 3       100706    105500    1055
# 4       100724    100500    1005
# 5       100751    105100    1051
# 6       100760    100700    1007
# 7       100812    100800    1008
# 8       100830    831000    8310
# 9       100858    100900    1009
# 10      100937    101200    1012
# 11      101028   1218200   12182
# 12      101073   1055400   10554
# 13      101116   1303906   13039
# 14      101143    101500    1015
# 15      101161    106000    1060
# 16      101189    100300    1003
# 17      101240    101700    1017
# 18      101277   4187200   41872
# 19      101286    101800    1018
# 20      101295    787100    7871
# 21      101301    569900    5699
# 22      101365    962107    9621
# 23      101435    101900    1019
# 24      101453   2199700   21997
# 25      101462    526000    5260
# 26      101471   3002500   30025
# ...

# %%
newframe = data[['INSTNM', 'RPY_3YR_RT','TUITIONFEE_IN','PREDDEG','PCTFLOAN', 'MALE_RPY_3YR_RT','FEMALE_RPY_3YR_RT','ACTCMMID', 'PELL_EVER']]
newframe
# Out:
#                                                  INSTNM         RPY_3YR_RT  \
# 0                              Alabama A & M University       0.2531554273
# 1                   University of Alabama at Birmingham        0.513963161
# 2                                    Amridge University       0.2307692308
# 3                   University of Alabama in Huntsville       0.5485090298
# 4                              Alabama State University       0.2185867473
# 5                             The University of Alabama       0.6019442985
# 6                     Central Alabama Community College       0.2510056315
# 7                               Athens State University       0.5038167939
# 8                       Auburn University at Montgomery       0.4418886199
# 9                                     Auburn University       0.7239612977
# 10                          Birmingham Southern College       0.7559912854
# ...

# %%
newframe.set_index('INSTNM')
cols = newframe.columns.drop('INSTNM')
newframe[cols] = newframe[cols].apply(pd.to_numeric, errors='coerce')
newframe = newframe.loc[newframe['PREDDEG'] == 3]
newframe = newframe.dropna()
newframe
# Out:
# /Users/tyler-matheny/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
#                                             INSTNM  RPY_3YR_RT  TUITIONFEE_IN  \
# 0                         Alabama A & M University    0.253155         9366.0
# 1              University of Alabama at Birmingham    0.513963         8040.0
# 3              University of Alabama in Huntsville    0.548509         9842.0
# 4                         Alabama State University    0.218587         9220.0
# 5                        The University of Alabama    0.601944        10470.0
# 8                  Auburn University at Montgomery    0.441889         9640.0
# ...

# %%
X = newframe['MALE_RPY_3YR_RT']
Y = newframe['FEMALE_RPY_3YR_RT']

# %%
# %matplotlib inline
sns.regplot(X,Y)

# %%
NEWVAR = data['TUITIONFEE_IN'] / data['TUITIONFEE_OUT']
newframe['ratio'] = NEWVAR

# %%
crap_degrees = newframe['PCIP24'] + newframe['PCIP23']
Y = newframe['RPY_3YR_RT']
X = newframe['PCTFLOAN']
# %matplotlib inline
sns.regplot(X, Y)

# %%
crap_degrees = newframe['PCIP24'] + newframe['PCIP23']
Y = newframe['RPY_3YR_RT']
X = newframe['UGDS_WHITE']
# %matplotlib inline
sns.regplot(X, Y)

# %%
crap_degrees = newframe['PCIP24'] + newframe['PCIP23']
Y = newframe['TUITIONFEE_OUT']
X = newframe['UGDS_BLACK'] 
Z = newframe['TUITIONFEE_IN']
# %matplotlib inline
sns.regplot(Z, Y)

# %%
x = newframe['FEMALE_RPY_3YR_RT']
x.median()
y = newframe['MALE_RPY_3YR_RT']
y.median()
z = newframe['FEMALE_RPY_3YR_RT'] / newframe['MALE_RPY_3YR_RT']

# %%
z.median()

# %%
X = newframe['CDR3']
Y = newframe['RPY_3YR_RT']
sns.regplot(X.astype(float), Y.astype(float))

# %%
Y.min()

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression

np.set_printoptions(precision=2)

newframe = newframe.dropna()

feature_names_loan = ['PELL_EVER', 'TUITIONFEE_IN']
X_loan = newframe[feature_names_loan]
y_loan = newframe['RPY_3YR_RT']
X_train, X_test, y_train, y_test = train_test_split(X_loan, y_loan,
                                                   random_state = 0)
linreg = LinearRegression().fit(X_train, y_train)

print('linear model intercept: {}'
     .format(linreg.intercept_))
print('linear model coeff:\n{}'
     .format(linreg.coef_))
print('R-squared score (training): {:.3f}'
     .format(linreg.score(X_train, y_train)))
print('R-squared score (test): {:.3f}'
     .format(linreg.score(X_test, y_test)))
# Out:
# linear model intercept: 1.0435360313470363
# linear model coeff:
# [-7.82e-01  1.00e-06]
# R-squared score (training): 0.621
# R-squared score (test): 0.564
